# %%
import pandas as pd

# %%
import numpy as np

# %%
import teste_download as td

# %%
teste = td.download("PETR4.SA", "2023-01-01", "2023-12-31")

# %%
petro = teste.baixar_dados()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
petro.head()
# Out:
#                 Close       High        Low       Open     Volume
# Date
# 2023-01-02  14.641592  15.210135  14.564934  15.037657   78424700
# 2023-01-03  14.271082  14.756580  14.136931  14.654370   96750300
# 2023-01-04  14.724638  15.069598  13.945287  14.028332  129504000
# 2023-01-05  15.254853  15.357064  14.788520  14.909895   73886000
# 2023-01-06  15.165418  15.535929  15.044043  15.293181   51851500

# %%
import analise_acao

# %%
petro = analise_acao.AnaliseAcao(ticker='PETR4.SA', inicio='2023-01-01', fim='2023-12-31')

# %%
dados = petro.baixar_dados()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Baixando dados de PETR4.SA...

# %%
teste = petro.tratar_dados()
# Out:
# Tratando dados...

# %%
teste
# Out:
#                 Close       High        Low       Open     Volume   Retorno
# Date
# 2023-01-02  14.641592  15.210135  14.564934  15.037657   78424700       NaN
# 2023-01-03  14.271082  14.756580  14.136931  14.654370   96750300 -0.025305
# 2023-01-04  14.724638  15.069598  13.945287  14.028332  129504000  0.031781
# 2023-01-05  15.254853  15.357064  14.788520  14.909895   73886000  0.036009
# 2023-01-06  15.165418  15.535929  15.044043  15.293181   51851500 -0.005863
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-21  30.099747  30.339619  29.835061  30.331346   30511900  0.000275
# 2023-12-22  30.389246  30.438873  30.083201  30.190730   31234700  0.009618
# 2023-12-26  30.877262  30.910345  30.463690  30.488504   23466800  0.016059
# 2023-12-27  30.902077  30.959977  30.711834  30.868990   19588500  0.000804
# 2023-12-28  30.802818  30.902075  30.637389  30.794545   21421900 -0.003212
#
# [248 rows x 6 columns]

# %%
teste = petro.executar_analise()
# Out:
# [                       0%                       ]
# [*********************100%***********************]  1 of 1 completed
# Baixando dados de PETR4.SA...
# Tratando dados...
# Plotando dados...

# %%
petro.executar_backtest()
# Out:
# Executando backtest com estratégia simples (Golden Cross)...
