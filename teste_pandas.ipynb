# %%
import pandas as pd

# %%
import numpy as np

# %%
import analise_acao

# %%
petro = analise_acao.AnaliseAcao(ticker='PETR4.SA', inicio='2023-01-01', fim='2023-12-31')

# %%
dados = petro.baixar_dados()
# Out:
# Baixando dados de PETR4.SA...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
teste = petro.tratar_dados()
# Out:
# Tratando dados...

# %%
teste
# Out:
#                 Close       High        Low       Open     Volume   Retorno
# Date
# 2023-01-02  14.641592  15.210135  14.564934  15.037657   78424700       NaN
# 2023-01-03  14.271079  14.756577  14.136928  14.654367   96750300 -0.025306
# 2023-01-04  14.724638  15.069598  13.945287  14.028332  129504000  0.031782
# 2023-01-05  15.254850  15.357062  14.788517  14.909892   73886000  0.036009
# 2023-01-06  15.165420  15.535931  15.044045  15.293183   51851500 -0.005862
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-21  30.099743  30.339615  29.835057  30.331342   30511900  0.000275
# 2023-12-22  30.389244  30.438871  30.083199  30.190728   31234700  0.009618
# 2023-12-26  30.877258  30.910342  30.463687  30.488500   23466800  0.016059
# 2023-12-27  30.902075  30.959975  30.711832  30.868988   19588500  0.000804
# 2023-12-28  30.802816  30.902073  30.637387  30.794543   21421900 -0.003212
#
# [248 rows x 6 columns]

# %%
teste = petro.executar_analise()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Baixando dados de PETR4.SA...
# Tratando dados...
# Plotando dados...

# %%
petro.executar_backtest()
# Out:
# Executando backtest com estratégia simples (Golden Cross)...
# Start                         2023-01-02 00:00:00
# End                           2023-12-28 00:00:00
# Period                          248 days 00:00:00
# Start Value                                 100.0
# End Value                              162.482124
# Total Return [%]                        62.482124
# Benchmark Return [%]                   110.378874
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                          1.722907
# Max Drawdown [%]                        12.049078
# Max Drawdown Duration            48 days 00:00:00
# Total Trades                                    7
# Total Closed Trades                             6
# Total Open Trades                               1
# Open Trade PnL                           3.593545
# Win Rate [%]                            66.666667
# Best Trade [%]                          47.530609
# Worst Trade [%]                         -8.045549
# Avg Winning Trade [%]                   16.664259
# Avg Losing Trade [%]                    -5.020377
# Avg Winning Trade Duration       34 days 00:00:00
# Avg Losing Trade Duration        11 days 12:00:00
# Profit Factor                            6.190112
# Expectancy                               9.814763
# Sharpe Ratio                             2.438569
# Calmar Ratio                             8.655868
# Omega Ratio                               1.51787
# Sortino Ratio                            3.809771
# Name: Close, dtype: object
